# %% [markdown]
# <a href="https://colab.research.google.com/github/mukheshbabu/machine-learning/blob/main/XG_Boost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --user xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.14.1)

# %% [markdown]
# **Loading and Exploring the Data**

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
diamonds.describe(exclude=np.number)
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# **How to Build an XGBoost DMatrix**

# %%
from sklearn.model_selection import train_test_split

# Extract feature and target arrays
X, y = diamonds.drop('price', axis=1), diamonds[['price']]

# %%
# Extract text features
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# Convert to Pandas category
for col in cats:
  X[col] = X[col].astype('category')

# %%
X.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
import xgboost as xgb

# Create regression matrices
dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %% [markdown]
# **Python XGBoost Regression**

# %%
import numpy as np

# Define hyperparameters for XGBoost
# Define hyperparameters
params = {"objective": "reg:squarederror", "tree_method": "hist"}

# Train the XGBoost model
bst = xgb.train(params, dtrain_reg, num_boost_round=100)

# Generate predictions
predicted = bst.predict(dtest_reg)

# Convert y_test to NumPy array
actual = y_test.values.flatten()

# Calculate MSE and RMSE
mse = np.mean((actual - predicted) ** 2)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("RMSE:", rmse)
# Out:
# MSE: 305655.6237797839
# RMSE: 552.8613060974551

# %% [markdown]
# **Training**

# %%
# Define hyperparameters


n = 100
model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
)

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import mean_squared_error

preds = model.predict(dtest_reg)

# %%
from sklearn.metrics import mean_squared_error

preds = model.predict(dtest_reg)

# Calculate MSE and then take the square root to get RMSE
mse = mean_squared_error(y_test, preds)  # Remove squared=False
rmse = np.sqrt(mse)

print(f"RMSE of the base model: {rmse:.3f}")
# Out:
# RMSE of the base model: 552.861

# %% [markdown]
# **Using Validation Sets During Training**

# %%
params = {"objective": "reg:squarederror", "tree_method": "hist"}
n = 100

evals = [(dtest_reg, "validation"), (dtrain_reg, "train")]


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=10 # Every ten rounds
)
# Out:
# [0]	validation-rmse:2817.90814	train-rmse:2874.49146
# [10]	validation-rmse:592.03160	train-rmse:548.36512
# [20]	validation-rmse:558.53485	train-rmse:491.09887
# [30]	validation-rmse:555.51015	train-rmse:469.58201
# [40]	validation-rmse:554.45666	train-rmse:454.32953
# [50]	validation-rmse:554.13365	train-rmse:438.68033
# [60]	validation-rmse:551.57888	train-rmse:425.38361
# [70]	validation-rmse:549.26109	train-rmse:414.71115
# [80]	validation-rmse:549.03952	train-rmse:405.41008
# [90]	validation-rmse:551.87206	train-rmse:391.04269
# [99]	validation-rmse:552.86131	train-rmse:383.48826

# %% [markdown]
# **XGBoost Early Stopping**

# %%
params = {"objective": "reg:squarederror", "tree_method": "hist"}
n = 5000

evals = [(dtest_reg, "validation"), (dtrain_reg, "train")]


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=250
)
# Out:
# [0]	validation-rmse:2817.90814	train-rmse:2874.49146
# [250]	validation-rmse:557.61263	train-rmse:283.21559
# [500]	validation-rmse:564.77532	train-rmse:201.44074
# [750]	validation-rmse:570.41258	train-rmse:155.76096
# [1000]	validation-rmse:574.22590	train-rmse:127.04692
# [1250]	validation-rmse:575.74609	train-rmse:105.13407
# [1500]	validation-rmse:577.88702	train-rmse:87.17633
# [1750]	validation-rmse:578.86698	train-rmse:75.08646
# [2000]	validation-rmse:579.64879	train-rmse:64.86890
# [2250]	validation-rmse:580.07445	train-rmse:56.54684
# [2500]	validation-rmse:580.65263	train-rmse:50.04183
# [2750]	validation-rmse:581.19185	train-rmse:44.39520
# [3000]	validation-rmse:581.63495	train-rmse:39.38436
# [3250]	validation-rmse:582.03607	train-rmse:35.32653
# [3500]	validation-rmse:582.04309	train-rmse:31.85327
# [3750]	validation-rmse:582.38781	train-rmse:28.94276
# [4000]	validation-rmse:582.60757	train-rmse:26.57816
# [4250]	validation-rmse:582.65767	train-rmse:24.39706
# [4500]	validation-rmse:582.92145	train-rmse:22.47317
# [4750]	validation-rmse:583.01244	train-rmse:20.83137
# [4999]	validation-rmse:583.12697	train-rmse:19.43452

# %%
n = 10000


model = xgb.train(
   params=params,
   dtrain=dtrain_reg,
   num_boost_round=n,
   evals=evals,
   verbose_eval=50,
   # Activate early stopping
   early_stopping_rounds=50
)
# Out:
# [0]	validation-rmse:2817.90814	train-rmse:2874.49146
# [50]	validation-rmse:554.13365	train-rmse:438.68033
# [100]	validation-rmse:553.73941	train-rmse:381.96310
# [150]	validation-rmse:551.25006	train-rmse:339.03503
# [200]	validation-rmse:556.18693	train-rmse:308.00219
# [250]	validation-rmse:557.61263	train-rmse:283.21559
# [300]	validation-rmse:559.05657	train-rmse:260.57418
# [350]	validation-rmse:560.65574	train-rmse:243.73253
# [400]	validation-rmse:562.32328	train-rmse:228.60311
# [450]	validation-rmse:563.18017	train-rmse:213.77568
# [500]	validation-rmse:564.77532	train-rmse:201.44074
# [550]	validation-rmse:566.71920	train-rmse:191.07173
# [600]	validation-rmse:567.56507	train-rmse:181.24398
# [650]	validation-rmse:568.47124	train-rmse:172.37143
# [700]	validation-rmse:569.60635	train-rmse:164.75530
# [750]	validation-rmse:570.41258	train-rmse:155.76096
# [800]	validation-rmse:570.93443	train-rmse:149.22645
# [850]	validation-rmse:571.72429	train-rmse:142.83847
# [900]	validation-rmse:572.77341	train-rmse:136.69104
# [950]	validation-rmse:574.11945	train-rmse:131.78701
# [1000]	validation-rmse:574.22590	train-rmse:127.04692
# [1050]	validation-rmse:574.70191	train-rmse:122.17938
# [1100]	validation-rmse:575.17303	train-rmse:117.47359
# [1150]	validation-rmse:575.08611	train-rmse:112.56570
# [1200]	validation-rmse:575.23924	train-rmse:107.85114
# [1250]	validation-rmse:575.74609	train-rmse:105.13407
# [1300]	validation-rmse:576.42202	train-rmse:101.21899
# [1350]	validation-rmse:576.91478	train-rmse:97.20741
# [1400]	validation-rmse:577.41121	train-rmse:93.79952
# [1450]	validation-rmse:577.63657	train-rmse:90.61812
# [1500]	validation-rmse:577.88702	train-rmse:87.17633
# [1550]	validation-rmse:578.04469	train-rmse:84.86173
# [1600]	validation-rmse:578.15658	train-rmse:82.25493
# [1650]	validation-rmse:578.49799	train-rmse:79.79848
# [1700]	validation-rmse:578.39134	train-rmse:77.57820
# [1750]	validation-rmse:578.86698	train-rmse:75.08646
# [1800]	validation-rmse:578.84107	train-rmse:72.80795
# [1850]	validation-rmse:578.65375	train-rmse:70.83423
# [1900]	validation-rmse:578.79884	train-rmse:68.68892
# [1950]	validation-rmse:579.34950	train-rmse:66.55417
# [2000]	validation-rmse:579.64879	train-rmse:64.86890
# [2050]	validation-rmse:579.63409	train-rmse:63.18339
# [2100]	validation-rmse:579.60186	train-rmse:61.50564
# [2150]	validation-rmse:579.87259	train-rmse:59.68049
# [2200]	validation-rmse:579.92365	train-rmse:58.08790
# [2250]	validation-rmse:580.07445	train-rmse:56.54684
# [2300]	validation-rmse:580.27799	train-rmse:54.93399
# [2350]	validation-rmse:580.42241	train-rmse:53.59138
# [2400]	validation-rmse:580.63714	train-rmse:52.22753
# [2450]	validation-rmse:580.70501	train-rmse:51.35937
# [2500]	validation-rmse:580.65263	train-rmse:50.04183
# [2550]	validation-rmse:580.86491	train-rmse:48.79403
# [2600]	validation-rmse:580.91181	train-rmse:47.78329
# [2650]	validation-rmse:581.15324	train-rmse:46.56813
# [2700]	validation-rmse:581.23327	train-rmse:45.41561
# [2750]	validation-rmse:581.19185	train-rmse:44.39520
# [2800]	validation-rmse:581.25623	train-rmse:43.52331
# [2850]	validation-rmse:581.32026	train-rmse:42.38782
# [2900]	validation-rmse:581.49749	train-rmse:41.43345
# [2950]	validation-rmse:581.54948	train-rmse:40.38950
# [3000]	validation-rmse:581.63495	train-rmse:39.38436
# [3050]	validation-rmse:581.77844	train-rmse:38.60468
# [3100]	validation-rmse:581.88966	train-rmse:37.80701
# [3150]	validation-rmse:581.95927	train-rmse:36.91297
# [3200]	validation-rmse:582.03671	train-rmse:36.19280
# [3250]	validation-rmse:582.03607	train-rmse:35.32653
# [3300]	validation-rmse:582.07845	train-rmse:34.72670
# [3350]	validation-rmse:582.00378	train-rmse:33.99247
# [3400]	validation-rmse:581.97327	train-rmse:33.25582
# [3450]	validation-rmse:582.09111	train-rmse:32.60442
# [3500]	validation-rmse:582.04309	train-rmse:31.85327
# [3550]	validation-rmse:582.14734	train-rmse:31.20087
# [3600]	validation-rmse:582.17457	train-rmse:30.64320
# [3650]	validation-rmse:582.26365	train-rmse:30.12000
# [3700]	validation-rmse:582.32823	train-rmse:29.45331
# [3750]	validation-rmse:582.38781	train-rmse:28.94276
# [3800]	validation-rmse:582.45310	train-rmse:28.44350
# [3850]	validation-rmse:582.47292	train-rmse:27.95044
# [3900]	validation-rmse:582.49668	train-rmse:27.48693
# [3950]	validation-rmse:582.53709	train-rmse:27.03156
# [4000]	validation-rmse:582.60757	train-rmse:26.57816
# [4050]	validation-rmse:582.54479	train-rmse:26.17856
# [4100]	validation-rmse:582.59947	train-rmse:25.72767
# [4150]	validation-rmse:582.59135	train-rmse:25.33494
# [4200]	validation-rmse:582.61778	train-rmse:24.84197
# [4250]	validation-rmse:582.65767	train-rmse:24.39706
# [4300]	validation-rmse:582.69703	train-rmse:23.98872
# [4350]	validation-rmse:582.75862	train-rmse:23.63434
# [4400]	validation-rmse:582.85504	train-rmse:23.24403
# [4450]	validation-rmse:582.88665	train-rmse:22.83123
# [4500]	validation-rmse:582.92145	train-rmse:22.47317
# [4550]	validation-rmse:582.93298	train-rmse:22.16575
# [4600]	validation-rmse:582.93875	train-rmse:21.83514
# [4650]	validation-rmse:582.96844	train-rmse:21.49700
# [4700]	validation-rmse:582.99198	train-rmse:21.16541
# [4750]	validation-rmse:583.01244	train-rmse:20.83137
# [4800]	validation-rmse:582.98079	train-rmse:20.52528
# [4850]	validation-rmse:583.00847	train-rmse:20.20986
# [4900]	validation-rmse:583.04461	train-rmse:19.90931
# [4950]	validation-rmse:583.08148	train-rmse:19.68561
# [5000]	validation-rmse:583.12902	train-rmse:19.42905
# [5050]	validation-rmse:583.13329	train-rmse:19.15289
# [5100]	validation-rmse:583.14836	train-rmse:18.93033
# [5150]	validation-rmse:583.14644	train-rmse:18.66480
# [5200]	validation-rmse:583.14552	train-rmse:18.43494
# [5250]	validation-rmse:583.14517	train-rmse:18.19098
# [5300]	validation-rmse:583.14274	train-rmse:17.95680
# [5350]	validation-rmse:583.15186	train-rmse:17.74925
# [5400]	validation-rmse:583.17786	train-rmse:17.55322
# [5450]	validation-rmse:583.17323	train-rmse:17.33834
# [5500]	validation-rmse:583.19869	train-rmse:17.19380
# [5550]	validation-rmse:583.21807	train-rmse:17.00426
# [5600]	validation-rmse:583.22223	train-rmse:16.80659
# [5650]	validation-rmse:583.27967	train-rmse:16.60000
# [5700]	validation-rmse:583.28867	train-rmse:16.43212
# [5750]	validation-rmse:583.30179	train-rmse:16.26590
# [5800]	validation-rmse:583.31467	train-rmse:16.09307
# [5850]	validation-rmse:583.32213	train-rmse:15.91984
# [5900]	validation-rmse:583.33267	train-rmse:15.75813
# [5950]	validation-rmse:583.35380	train-rmse:15.64069
# [6000]	validation-rmse:583.38527	train-rmse:15.47589
# [6050]	validation-rmse:583.40591	train-rmse:15.32847
# [6100]	validation-rmse:583.41047	train-rmse:15.19338
# [6150]	validation-rmse:583.44067	train-rmse:15.04584
# [6200]	validation-rmse:583.44366	train-rmse:14.92614
# [6250]	validation-rmse:583.42252	train-rmse:14.80232
# [6300]	validation-rmse:583.41402	train-rmse:14.68574
# [6350]	validation-rmse:583.43453	train-rmse:14.58699
# [6400]	validation-rmse:583.44546	train-rmse:14.45280
# [6450]	validation-rmse:583.44515	train-rmse:14.34137
# [6500]	validation-rmse:583.46092	train-rmse:14.24001
# [6550]	validation-rmse:583.46655	train-rmse:14.13574
# [6600]	validation-rmse:583.47638	train-rmse:14.03596
# [6650]	validation-rmse:583.49537	train-rmse:13.93866
# [6700]	validation-rmse:583.49707	train-rmse:13.86962
# [6750]	validation-rmse:583.50243	train-rmse:13.78578
# [6800]	validation-rmse:583.53019	train-rmse:13.69903
# [6850]	validation-rmse:583.55757	train-rmse:13.61843
# [6900]	validation-rmse:583.56552	train-rmse:13.52142
# [6950]	validation-rmse:583.55904	train-rmse:13.41892
# [7000]	validation-rmse:583.56660	train-rmse:13.33825
# [7050]	validation-rmse:583.57086	train-rmse:13.25629
# [7100]	validation-rmse:583.57718	train-rmse:13.19130
# [7150]	validation-rmse:583.58165	train-rmse:13.13230
# [7200]	validation-rmse:583.58432	train-rmse:13.05488
# [7250]	validation-rmse:583.60944	train-rmse:12.98045
# [7300]	validation-rmse:583.62892	train-rmse:12.91556
# [7350]	validation-rmse:583.62823	train-rmse:12.86211
# [7400]	validation-rmse:583.63418	train-rmse:12.80059
# [7450]	validation-rmse:583.64302	train-rmse:12.74514
# [7500]	validation-rmse:583.64644	train-rmse:12.69175
# [7550]	validation-rmse:583.64836	train-rmse:12.63786
# [7600]	validation-rmse:583.63726	train-rmse:12.57563
# [7650]	validation-rmse:583.63686	train-rmse:12.52514
# [7700]	validation-rmse:583.63941	train-rmse:12.47569
# [7750]	validation-rmse:583.65141	train-rmse:12.42700
# [7800]	validation-rmse:583.64137	train-rmse:12.36839
# [7850]	validation-rmse:583.65015	train-rmse:12.31488
# [7900]	validation-rmse:583.66789	train-rmse:12.27319
# [7950]	validation-rmse:583.67700	train-rmse:12.23461
# [8000]	validation-rmse:583.67395	train-rmse:12.20212
# [8050]	validation-rmse:583.68813	train-rmse:12.16992
# [8100]	validation-rmse:583.69737	train-rmse:12.13621
# [8150]	validation-rmse:583.69463	train-rmse:12.09247
# [8200]	validation-rmse:583.70378	train-rmse:12.06181
# [8250]	validation-rmse:583.71049	train-rmse:12.03344
# [8300]	validation-rmse:583.71631	train-rmse:12.00273
# [8350]	validation-rmse:583.72788	train-rmse:11.96910
# [8400]	validation-rmse:583.72488	train-rmse:11.93711
# [8450]	validation-rmse:583.73215	train-rmse:11.90888
# [8500]	validation-rmse:583.72952	train-rmse:11.88209
# [8550]	validation-rmse:583.72934	train-rmse:11.85847
# [8600]	validation-rmse:583.73384	train-rmse:11.83359
# [8650]	validation-rmse:583.73060	train-rmse:11.81121
# [8700]	validation-rmse:583.73982	train-rmse:11.78286
# [8750]	validation-rmse:583.74284	train-rmse:11.76291
# [8800]	validation-rmse:583.73575	train-rmse:11.74273
# [8850]	validation-rmse:583.73706	train-rmse:11.72099
# [8900]	validation-rmse:583.74264	train-rmse:11.69579
# [8950]	validation-rmse:583.73755	train-rmse:11.67338
# [9000]	validation-rmse:583.73445	train-rmse:11.64911
# [9050]	validation-rmse:583.73968	train-rmse:11.62989
# [9100]	validation-rmse:583.73746	train-rmse:11.60810
# [9150]	validation-rmse:583.74018	train-rmse:11.58962
# [9200]	validation-rmse:583.74131	train-rmse:11.57482
# [9250]	validation-rmse:583.74400	train-rmse:11.56033
# [9300]	validation-rmse:583.74978	train-rmse:11.54168
# [9350]	validation-rmse:583.75733	train-rmse:11.52353
# [9400]	validation-rmse:583.76343	train-rmse:11.50902
# [9450]	validation-rmse:583.76034	train-rmse:11.49060
# [9500]	validation-rmse:583.76321	train-rmse:11.47572
# [9550]	validation-rmse:583.76783	train-rmse:11.46459
# [9600]	validation-rmse:583.77176	train-rmse:11.44873
# [9650]	validation-rmse:583.77082	train-rmse:11.43725
# [9700]	validation-rmse:583.77155	train-rmse:11.42317
# [9750]	validation-rmse:583.77190	train-rmse:11.41227
# [9800]	validation-rmse:583.77242	train-rmse:11.40047
# [9850]	validation-rmse:583.77521	train-rmse:11.38981
# [9900]	validation-rmse:583.77739	train-rmse:11.37966
# [9950]	validation-rmse:583.77453	train-rmse:11.37051
# [9999]	validation-rmse:583.77508	train-rmse:11.35970

# %% [markdown]
# **XGBoost Cross Validation**

# %%
params = {"objective": "reg:squarederror", "tree_method": "hist"}
n = 1000

results = xgb.cv(
   params, dtrain_reg,
   num_boost_round=n,
   nfold=5,
   early_stopping_rounds=20
)

# %%
results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0      2874.224552        9.424846     2876.318793      36.995997
# 1      2088.350837        7.595382     2093.063623      25.351925
# 2      1552.629638        4.974140     1560.552731      19.550836
# 3      1185.994963        4.133544     1198.669943      14.648669
# 4       943.402904        4.757288      962.349383      11.724038

# %%
best_rmse = results['test-rmse-mean'].min()

best_rmse
550.8959336674216
# Out:
# 550.8959336674216

# %% [markdown]
# **XGBoost Classification**

# %%
from sklearn.preprocessing import OrdinalEncoder

X, y = diamonds.drop("cut", axis=1), diamonds[['cut']]

# Encode y to numeric
y_encoded = OrdinalEncoder().fit_transform(y)

# Extract text features
cats = X.select_dtypes(exclude=np.number).columns.tolist()

# Convert to pd.Categorical
for col in cats:
   X[col] = X[col].astype('category')

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, random_state=1, stratify=y_encoded)

# %%
# Create classification matrices
dtrain_clf = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_clf = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
params = {"objective": "multi:softprob", "tree_method": "hist", "num_class": 5}
n = 1000

results = xgb.cv(
   params, dtrain_clf,
   num_boost_round=n,
   nfold=5,
   metrics=["mlogloss", "auc", "merror"],
)

# %%
results.keys()

pd.Index(['train-mlogloss-mean', 'train-mlogloss-std', 'train-auc-mean',

      'train-auc-std', 'train-merror-mean', 'train-merror-std',

      'test-mlogloss-mean', 'test-mlogloss-std', 'test-auc-mean',

      'test-auc-std', 'test-merror-mean', 'test-merror-std'],

     dtype='object')
# Out:
# Index(['train-mlogloss-mean', 'train-mlogloss-std', 'train-auc-mean',
#        'train-auc-std', 'train-merror-mean', 'train-merror-std',
#        'test-mlogloss-mean', 'test-mlogloss-std', 'test-auc-mean',
#        'test-auc-std', 'test-merror-mean', 'test-merror-std'],
#       dtype='object')

# %% [markdown]
# **XGBoost Native vs. XGBoost Sklearn**

# %%
import xgboost as xgb

# Train a model using the scikit-learn API
xgb_classifier = xgb.XGBClassifier(n_estimators=100, objective='binary:logistic', tree_method='hist', eta=0.1, max_depth=3, enable_categorical=True)
xgb_classifier.fit(X_train, y_train)

# Convert the model to a native API model
model = xgb_classifier.get_booster()
